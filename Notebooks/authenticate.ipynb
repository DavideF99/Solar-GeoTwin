# %%
import ee
ee.Authenticate() 
# This opens a browser to link your Google Cloud Project.
ee.Initialize(project='solar-geoai-dferreri45')

# %%
import ee# Re-initialize with your project ID
ee.Initialize(project='solar-geoai-dferreri45')

# Test: Print the metadata of a single Sentinel-2 image
print(ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED").first().getInfo())
# Out:
# {'type': 'Image', 'bands': [{'id': 'B1', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [1830, 1830], 'crs': 'EPSG:32631', 'crs_transform': [60, 0, 600000, 0, -60, 3100020]}, {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [10980, 10980], 'crs': 'EPSG:32631', 'crs_transform': [10, 0, 600000, 0, -10, 3100020]}, {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [10980, 10980], 'crs': 'EPSG:32631', 'crs_transform': [10, 0, 600000, 0, -10, 3100020]}, {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [10980, 10980], 'crs': 'EPSG:32631', 'crs_transform': [10, 0, 600000, 0, -10, 3100020]}, {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [5490, 5490], 'crs': 'EPSG:32631', 'crs_transform': [20, 0, 600000, 0, -20, 31000
# ...
